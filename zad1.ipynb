# %% [markdown]
# <a href="https://colab.research.google.com/github/wiktorstudia/lecture1/blob/main/zad1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Salary Data (2).csv').dropna()

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Years of Experience', y='Salary')

plt.title('Zarobki a doświadczenie')
plt.xlabel('Lata doświadczenia')
plt.ylabel('Wynagrodzenie')

plt.tight_layout()
plt.show()
